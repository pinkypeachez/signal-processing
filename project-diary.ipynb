# %% [markdown]
# https://www.emotiv.com/de/blog/basics-of-neural-oscillations?srsltid=AfmBOoquKVQt4mHeMvInwFWqTv2xsoHGNpz5f34g8hCZhORTXjLVp14G

# %% [markdown]
# Irgendein Problem mit psychopy Installation:
# - ```pip install psychopy --no-deps``` hat funktioniert
#
# Bzw PsychoPy ist nicht für Python 3.12 supported. Offiziell empfohlen und getestet ist Python 3.10 (teilweise 3.8).
#
# Neues venv mit Python 3.10 (fuer PsychoPy):
# - py -3.10 -m venv .mi-bci
# - .mi-bci\Scripts\activate
# - pip install -r requirements.txt
# - pip freeze > requirements.txt
#
# P.S. spaeter auf pygame mit Timing umziehen
